# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = "https://raw.githubusercontent.com/pyhub-kr/offline-abc-bootcamp-2023/main/data/titanic/titanic_train.csv"

df = pd.read_csv(url)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
column_names = ["Survived", "Pclass", "SibSp", "Parch", "Age", "Fare"]
df[column_names].corr() #상관계수 파악 용어느낌? only 숫자로 표현됨
# Out:
#           Survived    Pclass     SibSp     Parch       Age      Fare
# Survived  1.000000 -0.338481 -0.035322  0.081629 -0.077221  0.257307
# Pclass   -0.338481  1.000000  0.083081  0.018443 -0.369226 -0.549500
# SibSp    -0.035322  0.083081  1.000000  0.414838 -0.308247  0.159651
# Parch     0.081629  0.018443  0.414838  1.000000 -0.189119  0.216225
# Age      -0.077221 -0.369226 -0.308247 -0.189119  1.000000  0.096067
# Fare      0.257307 -0.549500  0.159651  0.216225  0.096067  1.000000

# %%
import seaborn as sns

# %%
"%.2f" % 3.141592653 #fmt="2f"에 대한 설명사례
# Out:
# '3.14'

# %%
sns.heatmap(
    df[column_names].corr(),
    annot=True,
    fmt=".2f",
    cmap="coolwarm"
) 
#첫번쨰 인자는 data 형태로 호출 됨        
#두번째 인자부터는 또 달라짐 
#fmt = "2f"
# Out:
# <Axes: >

# %%
def mysum1(x, y):
    return 10 * x + y

mysum(1, 2) #positional argument
mysum(2, 1)
mysum(x=1, y=2)
mysum(y=2, x=1) #키워드 인자가 동일

def mysum2(x, *, y):
    return 10 * x + y

mysum(1, 2) #positional argument
mysum(2, 1)
mysum(x=1, y=2)
mysum(y=2, x=1) #키워드 인자가 동일
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       1 def mysum1(x, y):
#       2     return 10 * x + y
# ----> 4 mysum(1, 2) #positional argument
#       5 mysum(2, 1)
#       6 mysum(x=1, y=2)
#
# NameError: name 'mysum' is not defined

# %%
df["Embarked"].value_counts().plot(kind="bar") # Embarked 칼럼 막대그래프 화
# Out:
# <Axes: xlabel='Embarked'>

# %%
sns.countplot(data=df, x="Embarked")
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
sns.countplot(data=df, x="Embarked", hue="Survived")
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
df["Age"].hist(bins=40)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
figure, [ax1, ax2] = plt.subplots(1, 2, figsize=(12, 8))

sns.violinplot(
    df,
    x="Pclass",
    y="Age",
    hue="Survived",
    spilt=True,
    inner="quartile",
    ax=ax1
)

sns.violinplot(
    df,
    x="Sex",
    y="Age",
    hue="Survived",
    spilt=True,
    inner="quartile",
    ax=ax2
)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>
