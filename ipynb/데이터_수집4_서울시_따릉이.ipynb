# %% [markdown]
# # 데이터 가져와서 구체화 해보기

# %%
import requests

# %%
json_url = "https://www.bikeseoul.com/app/station/getStationRealtimeStatus.do"

# %%
res = requests.get(json_url)
res
# Out:
# <Response [200]>

# %% [markdown]
# # json 문자열을 파이썬 객체화

# %%
res.text

import json

response_dict = json.loads(res.text)
response_dict.keys()
# Out:
# dict_keys(['stationImgPath', 'appUserSessionVO', 'loginYn', 'realtimeList', 'sessionId', 'stationVO', 'checkResult'])

# %%
station_list = response_dict["realtimeList"]
len(station_list)
# Out:
# 87

# %%
import pandas as pd

# %%
df = pd.DataFrame(station_list)
print(df.shape)
df.head()
# Out:
# (87, 11)
#   stationId stationImgFileName             stationName stationLongitude  \
# 0    ST-116                                 300. 정동사거리     126.96923065
# 1    ST-126                                310. 청계광장 옆     126.97747040
# 2    ST-134                              318. 광교사거리 남측     126.98231506
# 3    ST-136                         320. 을지로입구역 4번출구 앞     126.98358917
# 4    ST-137                     321. KEB 하나금융그룹 명동사옥 옆     126.98413849
#
#   stationLatitude rackTotCnt parkingBikeTotCnt stationSeCd parkingQRBikeCnt  \
# 0     37.56805038          6                 0     RAK_002                0
# 1     37.56887817          8                 0     RAK_002               13
# 2     37.56863403         10                 0     RAK_002               13
# 3     37.56622314         17                 0     RAK_002               15
# 4     37.56546402         15                 0     RAK_002                3
#
#   parkingELECBikeCnt  mode
# 0                  0  None
# 1                  2  None
# 2                  1  None
# 3                  0  None
# 4                  0  None

# %% [markdown]
# # 지도 시각화

# %%
import folium

center= [45.5236, -122.6750]

m = folium.Map(location=center, zoom_start=13)

marker = folium.Marker(
    center,
    popup="팝업 메시지",
    tooltip="툴팁 메시지"
)

marker.add_to(m)

m

# %%
center_lat = sum([float(station["stationLatitude"]) for station in station_list]) / len(station_list)
center_lng = sum([float(station["stationLongitude"]) for station in station_list]) / len(station_list)
center_lat, center_lng
# Out:
# (37.56225406080459, 126.98923729229887)

# %%
center_lat = df["stationLatitude"].astype("float").mean()
center_lng = df["stationLongitude"].astype("float").mean()
center_lat, center_lng
# Out:
# (37.56225406080459, 126.98923729229885)

# %%
folium_map = folium.Map(
    [center_lat, center_lng],
    zoom_start=15,
)

for station in station_list:
  lat = station["stationLatitude"]
  lng = station["stationLongitude"]
  name = station["stationName"]
  marker = folium.Marker(
      [lat, lng],
      tooltip=name,
  )
  marker.add_to(folium_map)

folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2cebd45dfaa007dfb820090c6ae0a4ff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2cebd45dfaa007dfb820090c6ae0a4ff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2cebd45dfaa007dfb820090c6ae0a4ff = L.map(
#                 &quot;map_2cebd45dfaa007dfb820090c6ae0a4ff&quot;,
#                 {
#                     center: [37.56225406080459, 126.98923729229885],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_13438bfe395129e5bce143652419809d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2cebd45dfaa007dfb820090c6ae0a4ff);
#
#
#             var marker_dd058bc6c6da1c67a77178fd6cd057e2 = L.marker(
#                 [37.56805038, 126.96923065],
#                 {}
#             ).addTo(map_2cebd45dfaa007dfb820090c6ae0a4ff);
#
#
#             marker_dd058bc6c6da1c67a77178fd6cd057e2.bindTooltip(
#                 `&lt;div&gt;
#                      300. 정동사거리
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4869b3c4cdf8294bb9edf395a74e33cd = L.marker(
#                 [37.56887817, 126.9774704],
#                 {}
#             ).addTo(map_2cebd45dfaa007dfb820090c6ae0a4ff);
#
#
#             marker_4869b3c4cdf8294bb9edf395a74e33cd.bindTooltip(
#                 `&lt;div&gt;
#                      310. 청계광장 옆
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_92b8be113b9852e4ce5f936e90f55394 = L.marker(
#                 [37.56863403, 126.98231506],
#                 {}
#             ).addTo(map_2cebd45dfaa007dfb820090c6ae0a4ff);
#
#
#             marker_92b8be113b9852e4ce5f936e90f55394.bindTooltip(
#                 `&lt;div&gt;
#                      318. 광교사거리 남측
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ebfca86724b2452de02a142369961839 = L.marker(
#                 [37.56622314, 126.98358917],
#                 {}
#             ).addTo(map_2cebd45dfaa007dfb820090c6ae0a4ff);
#
#
#             marker_ebfca86724b2452de02a142369961839.bindTooltip(
#                 `&lt;div&gt;
#                      320. 을지로입구역 4번출구 앞
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d26c748b6324a49816462632bf2cbbc7 = L.marker(
#                 [37.56546402, 126.98413849],
#                 {}
#             ).addTo(map_2cebd45dfaa007dfb820090c6ae0a4ff);
#
#
#             marker_d26c748b6324a49816462632bf2cbbc7.bindTooltip(
#                 `&lt;div&gt;
#                      321. KEB 하나금융그룹 명동사옥 옆
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2a2b408d40fbc2d3191163e40e44e171 = L.marker(
#                 [37.56447601, 126.98696899],
#                 {}
#             ).addTo(map_2cebd45dfaa007dfb820090c6ae0a4ff);
#
#
#             marker_2a2b408d40fbc2d3191163e40e44e171.bindTooltip(
#                 `&lt;div&gt;
#                      322. 명동성당 앞
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b8c67e26c04f02b72c774faa4b7eea2d = L.marker(
#                 [37.56143188, 126.98069763],
#                 {}
#             ).addTo(map_2cebd45dfaa007dfb820090c6ae0a4ff);
#
#
#             marker_b8c67e26c04f02b72c774faa4b7eea2d.bindTooltip(
#                 `&lt;div&gt;
#                      324. 신세계백화점 본점 앞
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_186c8eacd8a0f510705add9d5ddbc507 = L.marker(
#                 [37.56638336, 126.98720551],
#                 {}
#             ).addTo(map_2cebd45dfaa007dfb820090c6ae0a4ff);
#
#
#             marker_186c8eacd8a0f510705add9d5ddbc507.bindTooltip(
#                 `&lt;div&gt;
#                      331. 을지로2가 사거리 북측
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cf5eae335c67fe6191afe909d4efe839 = L.marker(
#                 [37.56599045, 126.98779297],
#                 {}
#             ).addTo(map_2cebd45dfaa007dfb820090c6ae0a4ff);
#
#
#             marker_cf5eae335c67fe6191afe909d4efe839.bindTooltip(
#                 `&lt;div&gt;
#                      332. 을지로2가 사거리 남측
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fba6eb16f591834f66737cf48ec94d10 = L.marker(
#                 [37.56144714, 126.993110
